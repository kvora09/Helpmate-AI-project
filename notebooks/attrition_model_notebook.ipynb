# %% [markdown]
# # Attrition Early Detection Notebook
# This notebook trains a multivariate stochastic polynomial attrition model.

# %%
# !python -m src.generate_sample_data

# %%
from src.data_utils import DataConfig, load_dataset\nfrom src.modeling import train_model\n\ndf = load_dataset(DataConfig(csv_path='data/attrition_dataset.csv'))\nresult = train_model(df)\nresult.metrics

# %%
# !python -m src.train --data data/attrition_dataset.csv --output artifacts

# %% [markdown]
# ### Next\nRun `streamlit run streamlit_app/app.py` for the dashboard, or use the Next.js starter frontend.
